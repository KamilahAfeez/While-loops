# %% [markdown]
# <a href="https://colab.research.google.com/github/KamilahAfeez/While-loops/blob/main/while_loop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#sum of natural numbers(numbers from 0 to 9)

n=int(input("Enter the number of natural numbers: "))
sum=0
i=0
while i<=n:
       sum+=i
       i+=1
print("The sum of the first",n,"natural numbers is",sum)
# Out:
# Enter the number of natura numbers: 50
# The sum of the first 50 natural numbers is 1275

# %%
n=int(input("Enter a number"))
sum=0
temp=n
while temp>0:
  last_digit=temp%10
  sum+=last_digit**3
  temp//=10
if n==sum:
   print(n,"is an Armstrong number")
else:
   print(n,"is not an Armstrong number")
# Out:
# Enter a number159
# 159 is not an Armstrong number

# %%
i=0
while i<=0:
   print("Intifity loop")
# Out:
# Streaming output truncated to the last 5000 lines.
# Intifity loop
# Intifity loop
# Intifity loop
# Intifity loop
# Intifity loop
# Intifity loop
# Intifity loop
# Intifity loop
# Intifity loop
# Intifity loop
# Intifity loop
# Intifity loop
# Intifity loop
# Intifity loop
# Intifity loop
# Intifity loop
# Intifity loop
# Intifity loop
# Intifity loop
# Intifity loop
# Intifity loop
# Intifity loop
# Intifity loop
# Intifity loop
# Intifity loop
# Intifity loop
# Intifity loop
# Intifity loop
# Intifity loop
# Intifity loop
# Intifity loop
# Intifity loop
# Intifity loop
# Intifity loop
# Intifity loop
# Intifity loop
# Intifity loop
# Intifity loop
# Intifity loop
# Intifity loop
# Intifity loop
# Intifity loop
# Intifity loop
# Intifity loop
# Intifity loop
# Intifity loop
# Intifity loop
# Intifity loop
# Intifity loop
# Intifity loop
# Intifity loop
# Intifity loop
# Intifity loop
# Intifity loop
# Intifity loop
# Intifity loop
# Intifity loop
# Intifity loop
# Intifity loop
# ...
